# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.facecolor'] = 'white'  # Figure background
plt.rcParams['axes.facecolor'] = 'white'   # Axes background
plt.rcParams['figure.dpi'] = 100

# %%
df = pd.read_csv('proj_data.csv', index_col=0)
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#            date       adj_prc           prc          high           low  \
# 3702 2024-11-05  69359.562500  69359.562500  70522.789062  67458.867188
# 2220 2024-11-05      1.000037      1.000037      1.001009      0.999724
# 2553 2024-11-05   2422.650635   2422.650635   2478.618896   2380.601318
# 2553 2024-11-05      0.170180      0.170180      0.178840      0.158179
# 2553 2024-11-05    563.612061    563.612061    571.970520    551.252258
# ...         ...           ...           ...           ...           ...
# 334  2018-10-09      0.005635      0.005635      0.005639      0.005574
# 333  2018-10-08      0.005578      0.005578      0.005652      0.005550
# 333  2018-10-08    229.255005    229.255005    230.764999    224.557007
# 1482 2018-10-08   6652.229980   6652.229980   6675.060059   6576.040039
# 333  2018-10-08     10.506600     10.506600     10.632100     10.458900
#
#               open           vol      tick       ret    logret       mom  \
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
plt.subplot(221)
btc = df[df.tick == 'BTC-USD']
plt.plot(btc['date'], btc['adj_prc'])
plt.title('Price of Bitcoin')
plt.tight_layout()  
plt.xlabel('Date')
plt.ylabel('Price ($)')

plt.subplot(222)
eth = df[df.tick == 'ETH-USD']
plt.plot(eth['date'], eth['adj_prc'], color='green')
plt.title('Price of Ethereum')
plt.tight_layout()  
plt.xlabel('Date')
plt.ylabel('Price ($)')

plt.subplot(223)
doge = df[df.tick == 'DOGE-USD']
plt.plot(doge['date'], doge['adj_prc'], color='orange')
plt.title('Price of Dogecoin')
plt.tight_layout()  
plt.xlabel('Date')
plt.ylabel('Price ($)')

plt.subplot(224)
bnb = df[df.tick == 'BNB-USD']
plt.plot(bnb['date'], bnb['adj_prc'], color='lightcoral')
plt.title('Price of Binance Coin')
plt.tight_layout()
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 8))
plt.subplot(221)
plt.hist(btc['logret'], bins=100)
plt.title('Histogram of Historical Bitcoin Log Returns')
plt.tight_layout()  
plt.xlabel('Daily Log Return')
plt.ylabel('Frequency')

plt.subplot(222)
plt.hist(eth['logret'], color = 'green', bins=100)
plt.title('Histogram of Historical Etherum Log Returns')
plt.tight_layout()  
plt.xlabel('Daily Log Return')
plt.ylabel('Frequency')


plt.subplot(223)
plt.hist(doge['logret'], color = 'orange', bins=100)
plt.title('Histogram of Historical Dogecoin Log Returns')
plt.tight_layout()  
plt.xlabel('Daily Log Return')
plt.ylabel('Frequency')

plt.subplot(224)
plt.hist(bnb['logret'], color = 'lightcoral', bins=100)
plt.title('Histogram of Historical Binance Coin Log Returns')
plt.tight_layout()  
plt.xlabel('Daily Log Return')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
#fig, axes = plt.subplots(2, 2, figsize=(10, 8))
#plt.subplot(221)
plt.hist(btc['logret'], bins=100)
plt.title('Histogram of Historical Bitcoin Log Returns')
plt.tight_layout()  
plt.xlabel('Daily Log Return')
plt.ylabel('Frequency')

#plt.subplot(222)
plt.hist(eth['logret'], color = 'green', bins=100)
plt.title('Histogram of Historical Etherum Log Returns')
plt.tight_layout()  
plt.xlabel('Daily Log Return')
plt.ylabel('Frequency')


#plt.subplot(223)
plt.hist(doge['logret'], color = 'orange', bins=100)
plt.title('Histogram of Historical Dogecoin Log Returns')
plt.tight_layout()  
plt.xlabel('Daily Log Return')
plt.ylabel('Frequency')

#plt.subplot(224)
plt.hist(bnb['logret'], color = 'lightcoral', bins=100)
plt.title('Histogram of Historical Binance Coin Log Returns')
plt.tight_layout()  
plt.xlabel('Daily Log Return')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
