# %%
import numpy as np
import pandas as pd
import yfinance as yf
import pandas_ta as ta
import matplotlib.pyplot as plt
import scipy 
import yfinance as yf

# %%
bitcoin = yf.Ticker("BTC-USD")

# Fetch historical market data
data = pd.DataFrame(bitcoin.history(period="10y"))  # Change the period as needed
#data = pd.DataFrame(bitcoin.history(period='20y'))  # Change the period as needed

data
# Out:
#                                    Open          High           Low  \
# Date
# 2014-11-07 00:00:00+00:00    349.817993    352.731995    341.776001
# 2014-11-08 00:00:00+00:00    342.153992    347.032013    342.153992
# 2014-11-09 00:00:00+00:00    345.376007    363.626007    344.255005
# 2014-11-10 00:00:00+00:00    362.265015    374.816010    357.561005
# 2014-11-11 00:00:00+00:00    365.856995    371.309998    363.734985
# ...                                 ...           ...           ...
# 2024-11-03 00:00:00+00:00  69296.382812  69361.656250  67482.523438
# 2024-11-04 00:00:00+00:00  68742.132812  69433.179688  66803.648438
# 2024-11-05 00:00:00+00:00  67811.171875  70522.789062  67458.867188
# 2024-11-06 00:00:00+00:00  69358.500000  76460.156250  69322.031250
# 2024-11-07 00:00:00+00:00  75634.906250  76850.507812  74494.718750
#
#                                   Close        Volume  Dividends  Stock Splits
# Date
# 2014-11-07 00:00:00+00:00    342.415009      16834200        0.0           0.0
# 2014-11-08 00:00:00+00:00    345.488007       8535470        0.0           0.0
# 2014-11-09 00:00:00+00:00    363.264008      24205600        0.0           0.0
# 2014-11-10 00:00:00+00:00    366.924011      30450100        0.0           0.0
# 2014-11-11 00:00:00+00:00    367.695007      15838900        0.0           0.0
# ...                                 ...           ...        ...           ...
# 2024-11-03 00:00:00+00:00  68741.117188   34868307655        0.0           0.0
# 2024-11-04 00:00:00+00:00  67811.507812   41184819348        0.0           0.0
# 2024-11-05 00:00:00+00:00  69359.562500   46046889204        0.0           0.0
# 2024-11-06 00:00:00+00:00  75639.078125  118592653963        0.0           0.0
# 2024-11-07 00:00:00+00:00  75958.460938   63475466240        0.0           0.0
#
# [3654 rows x 7 columns]

# %%
ticker = "BTC-USD"
ydf = yf.download(ticker)
ydf.to_csv(f'y{ticker}.csv')

btc = pd.read_csv(f'y{ticker}.csv')
btc = btc.drop([0,1])
btc['Date'] = pd.to_datetime(btc['Close']).dt.date
btc= btc.set_index('Date')
btc = btc.drop(['Close'], axis = 1)
btc = btc.reset_index()
btc['Ticker'] = ticker
ydf
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Joshua Hoagland\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\Joshua Hoagland\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslibs\parsing.pyx:289, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ValueError: Given date string 457.3340148925781 not likely a datetime
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Joshua Hoagland\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:616, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime for "457.3340148925781" at position 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 7
#       5 btc = pd.read_csv(f'y{ticker}.csv')
#       6 btc = btc.drop([0,1])
# ----> 7 btc['Date'] = pd.to_datetime(btc['Close']).dt.date
#       8 btc= btc.set_index('Date')
#       9 btc = btc.drop(['Close'], axis = 1)
#
# File c:\Users\Joshua Hoagland\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:1068, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1066         result = arg.map(cache_array)
#    1067     else:
# -> 1068         values = convert_listlike(arg._values, format)
#    1069         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1070 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\Joshua Hoagland\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:438, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     436 assert format is None or infer_datetime_format
#     437 utc = tz == "utc"
# --> 438 result, tz_parsed = objects_to_datetime64ns(
#     439     arg,
#     440     dayfirst=dayfirst,
#     441     yearfirst=yearfirst,
#     442     utc=utc,
#     443     errors=errors,
#     444     require_iso8601=require_iso8601,
#     445     allow_object=True,
#     446 )
#     448 if tz_parsed is not None:
#     449     # We can take a shortcut since the datetime64 numpy array
#     450     # is in UTC
#     451     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File c:\Users\Joshua Hoagland\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\arrays\datetimes.py:2177, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2175 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2176 try:
# -> 2177     result, tz_parsed = tslib.array_to_datetime(
#    2178         data.ravel("K"),
#    2179         errors=errors,
#    2180         utc=utc,
#    2181         dayfirst=dayfirst,
#    2182         yearfirst=yearfirst,
#    2183         require_iso8601=require_iso8601,
#    2184         allow_mixed=allow_mixed,
#    2185     )
#    2186     result = result.reshape(data.shape, order=order)
#    2187 except OverflowError as err:
#    2188     # Exception is raised when a part of date is greater than 32 bit signed int
#
# File c:\Users\Joshua Hoagland\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:427, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\Joshua Hoagland\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:683, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\Joshua Hoagland\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:829, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\Users\Joshua Hoagland\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslib.pyx:819, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\Users\Joshua Hoagland\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslibs\parsing.pyx:289, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ValueError: Given date string 457.3340148925781 not likely a datetime present at position 0
